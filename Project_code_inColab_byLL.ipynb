# %% [markdown]
# # Download the dataset VOC2012

# %%
# !mkdir ./drive/My\ Drive/VOC2012
# %cd ./drive/My\ Drive/VOC2012

# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# !tar -xf VOCtrainval_11-May-2012.tar

# %% [markdown]
# # Download the dataset Benchmark

# %%
# !mkdir ./drive/My\ Drive/benchmark
# %cd ./drive/My\ Drive/benchmark

# !wget http://www.eecs.berkeley.edu/Research/Projects/CS/vision/grouping/semantic_contours/benchmark.tgz
# !tar -xf benchmark.tgz

# %% [markdown]
# # Install required packages

# %%
# %cd ./drive/My\ Drive/pytorch-semseg

# !pip install -r requirements.txt
# !pip install tensorboardX
# !pip install scipy==0.19.0
# !pip install pydensecrf

# %% [markdown]
# # Training

# %%
# !python train.py --config configs/fcn8s_pascal_adamdelta_1e-4.yml

# %% [markdown]
# # Validation

# %%
# !python validate.py --config configs/fcn8s_pascal_adamdelta.yml \
# --model_path runs/fcn8s_pascal/26208/fcn8s_pascal_best_model.pkl

# %% [markdown]
# # Visulization

# %%
# %cd ./drive/My\ Drive/pytorch-semseg

# %load_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_sgd_1e-10/71218

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_sgd_1e-10/31240

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_sgd_1e-10/26208

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-3/52035

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-4/11342

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-4/76429

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-4/52491

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-4_cosineannealing/56163

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-5/17752

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-5/80546

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs/fcn8s_pascal_adamdelta_1e-5/49867
